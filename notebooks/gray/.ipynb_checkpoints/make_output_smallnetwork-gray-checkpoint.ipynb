# %%
#files=glob.glob('*.png')
#fname=files[3]
fname="slide-2019-09-24T09-52-40-R1-S1.mrxs.png"

# %%
class_names=["Fat", "Muscular", "Vessle", "Gland", "Stroma", "Tumor", "Necrosis", "Epithelium"]
nclasses=len(class_names)

# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import scipy.signal
import argparse
from torch import nn
from torchsummary import summary

from skimage import color 

from albumentations import *
from albumentations.pytorch import ToTensor

import sklearn.feature_extraction.image

import matplotlib.cm

import torch

from torchvision.models import DenseNet

from tqdm.autonotebook import tqdm

from  skimage.color import rgb2gray


import glob

import dill as pickle

from skimage.color import rgb2gray, rgb2hed

from skimage.measure import * 
from skimage.filters import *
from skimage.morphology import *
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
def blend2Images(img, mask):
    if (img.ndim == 3):
        img = color.rgb2gray(img)
    if (mask.ndim == 3):
        mask = color.rgb2gray(mask)
    img = img[:, :, None] * 1.0  # can't use boolean
    mask = mask[:, :, None] * 1.0
    out = np.concatenate((mask, img, mask), 2)
    return out

# %%
patch_size=64
batch_size=128 #should be a power of 2

cmap= matplotlib.cm.tab10

# %%
import torch
device = torch.device('cuda')
checkpoint = torch.load("./trg_doublesimple_best_model.pth", map_location = device)

# %%
class SmallNetwork(nn.Module):
    def __init__(self):
        super(SmallNetwork,self).__init__()
        
        self.encoder = nn.Sequential(
            nn.Conv2d(6, 6, kernel_size=5, padding=2),
            nn.ReLU(True),
            nn.BatchNorm2d(6),
            nn.Conv2d(6, 6, kernel_size=3),
            nn.ReLU(True),
            nn.BatchNorm2d(6),
            nn.Conv2d(6,8,stride=2,kernel_size=3),
            nn.ReLU(True),
            nn.BatchNorm2d(8),
            nn.Conv2d(8,8,stride=2,kernel_size=3),
            nn.ReLU(True),
            nn.BatchNorm2d(8),
            nn.Conv2d(8,8,stride=2,kernel_size=3),
            nn.ReLU(True),
            nn.BatchNorm2d(8)
        )


        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        

        self.final= nn.Sequential(
            nn.Linear(8, 16), #--- add dropout
            nn.ReLU(True),
            nn.BatchNorm1d(16),
            nn.Linear(16, 16),
            nn.ReLU(True),
            nn.Linear(16, nclasses),
        )
                          

        
    def forward(self,x):
        x = self.encoder(x)
        #x = self.decoder(x)
        x = self.avgpool(x)
        x = torch.flatten(x , 1)
        x = self.final(x)
        return x

# %%
device = torch.device('cuda')
model = SmallNetwork().to(device)
model.load_state_dict(checkpoint["model_dict"])

summary(model, input_size=(6, 64, 64))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-14cc71ef11dd> in <module>
#       1 device = torch.device('cuda')
#       2 model = SmallNetwork().to(device)
# ----> 3 model.load_state_dict(checkpoint["model_dict"])
#       4
#       5 summary(model, input_size=(6, 64, 64))
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#     837         if len(error_msgs) > 0:
#     838             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# --> 839                                self.__class__.__name__, "\n\t".join(error_msgs)))
#     840         return _IncompatibleKeys(missing_keys, unexpected_keys)
#     841
#
# RuntimeError: Error(s) in loading state_dict for SmallNetwork:
# 	Missing key(s) in state_dict: "encoder.12.weight", "encoder.12.bias", "encoder.14.weight", "encoder.14.bias", "encoder.14.running_mean", "encoder.14.running_var".
# 	size mismatch for encoder.0.weight: copying a param with shape torch.Size([6, 6, 3, 3]) from checkpoint, the shape in current model is torch.Size([6, 6, 5, 5]).
# 	size mismatch for encoder.3.weight: copying a param with shape torch.Size([8, 6, 3, 3]) from checkpoint, the shape in current model is torch.Size([6, 6, 3, 3]).
# 	size mismatch for encoder.3.bias: copying a param with shape torch.Size([8]) from checkpoint, the shape in current model is torch.Size([6]).
# 	size mismatch for encoder.5.weight: copying a param with shape torch.Size([8]) from checkpoint, the shape in current model is torch.Size([6]).
# 	size mismatch for encoder.5.bias: copying a param with shape torch.Size([8]) from checkpoint, the shape in current model is torch.Size([6]).
# 	size mismatch for encoder.5.running_mean: copying a param with shape torch.Size([8]) from checkpoint, the shape in current model is torch.Size([6]).
# 	size mismatch for encoder.5.running_var: copying a param with shape torch.Size([8]) from checkpoint, the shape in current model is torch.Size([6]).
# 	size mismatch for encoder.6.weight: copying a param with shape torch.Size([8, 8, 3, 3]) from checkpoint, the shape in current model is torch.Size([8, 6, 3, 3]).

# %%
def divide_batch(l, n): 
    for i in range(0, l.shape[0], n):  
        yield l[i:i + n,::]

# %%
resize=1
img = cv2.cvtColor(cv2.imread(fname),cv2.COLOR_BGR2RGB)
img=cv2.resize(img,(int(img.shape[1]*resize),int(img.shape[0]*resize)))
img=np.pad(img,[(100,100),(100,100),(0,0)],'constant',constant_values=255)



hed=rgb2hed(img)
mask=hed[:,:,0]>-.8
mask=remove_small_objects(mask,150)

# %%
mask[img.sum(axis=2)<100]=0

mask[img.sum(axis=2)>700]=0

mask[0:patch_size,:]=0;
mask[:,0:patch_size]=0;

mask[:,-patch_size-1:]=0
mask[-patch_size-1:,:]=0

# %%
plt.imshow(mask)

# %%
def random_subset(a, b, nitems):
    assert len(a) == len(b)
    idx = np.random.randint(0,len(a),nitems)
    return a[idx], b[idx]

# %%
max_number_samples=50000
[rs,cs]=mask.nonzero()
[rs,cs]=random_subset(rs,cs,max_number_samples)

centers = [(r,c) for r,c in zip(rs,cs)]

# rps=regionprops(label(mask))

# centers=[rp.centroid for rp in rps]
# centers=np.round(np.asarray(centers))

npatches=len(centers)
#output = np.zeros((npatches,3,patch_size//patch_size,patch_size//patch_size))
arr_out = np.zeros((npatches,6,patch_size,patch_size))

# %%
img_transform = Compose([
#        Normalize(mean=(140, 91, 186), std=(51,57,27), max_pixel_value=1),
       ToTensor()
    ])

# %%
rs=[]
cs=[]
for i, (r,c) in tqdm(enumerate(centers)):
    r=int(round(r))
    c=int(round(c))
    rs.append(r)
    cs.append(c)

    patch=img[r-patch_size//2:r+patch_size//2,c-patch_size//2:c+patch_size//2,:]
    patch2=img[r-patch_size:r+patch_size,c-patch_size:c+patch_size,:]
    patch2 = cv2.resize(patch2, (patch_size, patch_size), interpolation = cv2.INTER_AREA)
    arr_out[i,:,:,:] = np.concatenate((img_transform(image=patch)["image"], img_transform(image=patch2)["image"]), 0)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
clusterids=[]
for batch_arr in tqdm(divide_batch(arr_out,batch_size)):

    #arr_out_gpu = torch.from_numpy(batch_arr.transpose(0, 3, 1, 2) / 255).type('torch.FloatTensor').to(device)
    arr_out_gpu =  torch.from_numpy(batch_arr).type('torch.FloatTensor').to(device)

    # ---- get results
    clusterids.append(torch.argmax( model(arr_out_gpu),dim=1).detach().cpu().numpy())
clusterids=np.hstack(clusterids)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
labels = [class_names[i] for i in clusterids]
labels
# Out:
# ['Muscular',
#  'Gland',
#  'Necrosis',
#  'Fat',
#  'Muscular',
#  'Fat',
#  'Epithelium',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Tumor',
#  'Epithelium',
#  'Muscular',
#  'Stroma',
#  'Fat',
#  'Muscular',
#  'Muscular',
#  'Tumor',
#  'Vein',
#  'Vein',
#  'Necrosis',
#  'Stroma',
#  'Tumor',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Tumor',
#  'Vein',
#  'Tumor',
#  'Muscular',
#  'Gland',
#  'Stroma',
#  'Stroma',
#  'Fat',
#  'Necrosis',
#  'Fat',
#  'Stroma',
#  'Vein',
#  'Tumor',
#  'Necrosis',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Epithelium',
#  'Fat',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Gland',
#  'Tumor',
#  'Tumor',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Muscular',
#  'Muscular',
#  'Necrosis',
#  'Vein',
#  'Vein',
#  'Muscular',
#  'Vein',
#  'Tumor',
#  'Vein',
#  'Epithelium',
#  'Gland',
#  'Tumor',
#  'Epithelium',
#  'Muscular',
#  'Stroma',
#  'Vein',
#  'Tumor',
#  'Necrosis',
#  'Vein',
#  'Tumor',
#  'Vein',
#  'Necrosis',
#  'Stroma',
#  'Stroma',
#  'Epithelium',
#  'Fat',
#  'Epithelium',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Tumor',
#  'Fat',
#  'Fat',
#  'Stroma',
#  'Fat',
#  'Stroma',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Epithelium',
#  'Muscular',
#  'Muscular',
#  'Necrosis',
#  'Muscular',
#  'Vein',
#  'Gland',
#  'Tumor',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Necrosis',
#  'Gland',
#  'Muscular',
#  'Fat',
#  'Fat',
#  'Vein',
#  'Tumor',
#  'Gland',
#  'Tumor',
#  'Muscular',
#  'Epithelium',
#  'Fat',
#  'Muscular',
#  'Fat',
#  'Gland',
#  'Muscular',
#  'Necrosis',
#  'Vein',
#  'Fat',
#  'Muscular',
#  'Fat',
#  'Vein',
#  'Vein',
#  'Necrosis',
#  'Necrosis',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Necrosis',
#  'Tumor',
#  'Tumor',
#  'Stroma',
#  'Muscular',
#  'Muscular',
#  'Necrosis',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Stroma',
#  'Fat',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Tumor',
#  'Gland',
#  'Tumor',
#  'Epithelium',
#  'Necrosis',
#  'Stroma',
#  'Muscular',
#  'Tumor',
#  'Stroma',
#  'Vein',
#  'Tumor',
#  'Stroma',
#  'Vein',
#  'Stroma',
#  'Stroma',
#  'Fat',
#  'Fat',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Epithelium',
#  'Fat',
#  'Epithelium',
#  'Fat',
#  'Vein',
#  'Tumor',
#  'Gland',
#  'Tumor',
#  'Gland',
#  'Stroma',
#  'Muscular',
#  'Epithelium',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Fat',
#  'Stroma',
#  'Necrosis',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Necrosis',
#  'Vein',
#  'Muscular',
#  'Gland',
#  'Muscular',
#  'Fat',
#  'Vein',
#  'Vein',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Stroma',
#  'Muscular',
#  'Fat',
#  'Vein',
#  'Gland',
#  'Necrosis',
#  'Muscular',
#  'Necrosis',
#  'Epithelium',
#  'Stroma',
#  'Muscular',
#  'Fat',
#  'Epithelium',
#  'Gland',
#  'Tumor',
#  'Muscular',
#  'Muscular',
#  'Gland',
#  'Muscular',
#  'Tumor',
#  'Vein',
#  'Necrosis',
#  'Vein',
#  'Stroma',
#  'Gland',
#  'Tumor',
#  'Stroma',
#  'Muscular',
#  'Necrosis',
#  'Fat',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Epithelium',
#  'Tumor',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Vein',
#  'Muscular',
#  'Tumor',
#  'Stroma',
#  'Vein',
#  'Stroma',
#  'Fat',
#  'Muscular',
#  'Vein',
#  'Necrosis',
#  'Muscular',
#  'Vein',
#  'Fat',
#  'Necrosis',
#  'Stroma',
#  'Muscular',
#  'Stroma',
#  'Gland',
#  'Vein',
#  'Gland',
#  'Gland',
#  'Tumor',
#  'Stroma',
#  'Tumor',
#  'Tumor',
#  'Muscular',
#  'Fat',
#  'Muscular',
#  'Tumor',
#  'Vein',
#  'Vein',
#  'Tumor',
#  'Muscular',
#  'Necrosis',
#  'Vein',
#  'Gland',
#  'Gland',
#  'Epithelium',
#  'Vein',
#  'Vein',
#  'Muscular',
#  'Stroma',
#  'Necrosis',
#  'Vein',
#  'Muscular',
#  'Tumor',
#  'Gland',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Muscular',
#  'Muscular',
#  'Gland',
#  'Fat',
#  'Muscular',
#  'Vein',
#  'Vein',
#  'Stroma',
#  'Muscular',
#  'Necrosis',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Epithelium',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Stroma',
#  'Vein',
#  'Muscular',
#  'Necrosis',
#  'Vein',
#  'Tumor',
#  'Muscular',
#  'Vein',
#  'Stroma',
#  'Vein',
#  'Stroma',
#  'Muscular',
#  'Epithelium',
#  'Tumor',
#  'Fat',
#  'Stroma',
#  'Vein',
#  'Muscular',
#  'Fat',
#  'Vein',
#  'Gland',
#  'Vein',
#  'Necrosis',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Necrosis',
#  'Fat',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Tumor',
#  'Vein',
#  'Muscular',
#  'Tumor',
#  'Muscular',
#  'Muscular',
#  'Epithelium',
#  'Muscular',
#  'Necrosis',
#  'Necrosis',
#  'Tumor',
#  'Vein',
#  'Fat',
#  'Stroma',
#  'Stroma',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Epithelium',
#  'Stroma',
#  'Vein',
#  'Fat',
#  'Fat',
#  'Tumor',
#  'Necrosis',
#  'Vein',
#  'Muscular',
#  'Epithelium',
#  'Stroma',
#  'Vein',
#  'Fat',
#  'Muscular',
#  'Muscular',
#  'Necrosis',
#  'Stroma',
#  'Fat',
#  'Tumor',
#  'Vein',
#  'Stroma',
#  'Tumor',
#  'Vein',
#  'Muscular',
#  'Necrosis',
#  'Tumor',
#  'Vein',
#  'Muscular',
#  'Gland',
#  'Muscular',
#  'Stroma',
#  'Muscular',
#  'Necrosis',
#  'Necrosis',
#  'Necrosis',
#  'Gland',
#  'Muscular',
#  'Fat',
#  'Stroma',
#  'Tumor',
#  'Tumor',
#  'Tumor',
#  'Fat',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Vein',
#  'Fat',
#  'Fat',
#  'Epithelium',
#  'Muscular',
#  'Necrosis',
#  'Muscular',
#  'Tumor',
#  'Vein',
#  'Vein',
#  'Stroma',
#  'Muscular',
#  'Tumor',
#  'Tumor',
#  'Epithelium',
#  'Tumor',
#  'Stroma',
#  'Stroma',
#  'Muscular',
#  'Stroma',
#  'Epithelium',
#  'Vein',
#  'Vein',
#  'Tumor',
#  'Necrosis',
#  'Fat',
#  'Gland',
#  'Vein',
#  'Muscular',
#  'Necrosis',
#  'Stroma',
#  'Vein',
#  'Tumor',
#  'Stroma',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Gland',
#  'Epithelium',
#  'Muscular',
#  'Vein',
#  'Vein',
#  'Muscular',
#  'Vein',
#  'Gland',
#  'Gland',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Necrosis',
#  'Tumor',
#  'Tumor',
#  'Stroma',
#  'Stroma',
#  'Gland',
#  'Muscular',
#  'Muscular',
#  'Epithelium',
#  'Muscular',
#  'Gland',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Tumor',
#  'Tumor',
#  'Epithelium',
#  'Muscular',
#  'Tumor',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Necrosis',
#  'Vein',
#  'Muscular',
#  'Stroma',
#  'Fat',
#  'Necrosis',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Necrosis',
#  'Gland',
#  'Muscular',
#  'Muscular',
#  'Gland',
#  'Necrosis',
#  'Stroma',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Fat',
#  'Vein',
#  'Muscular',
#  'Necrosis',
#  'Vein',
#  'Vein',
#  'Fat',
#  'Tumor',
#  'Gland',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Vein',
#  'Stroma',
#  'Tumor',
#  'Vein',
#  'Tumor',
#  'Vein',
#  'Tumor',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Vein',
#  'Vein',
#  'Gland',
#  'Tumor',
#  'Muscular',
#  'Epithelium',
#  'Epithelium',
#  'Stroma',
#  'Epithelium',
#  'Gland',
#  'Fat',
#  'Necrosis',
#  'Fat',
#  'Fat',
#  'Necrosis',
#  'Tumor',
#  'Gland',
#  'Tumor',
#  'Muscular',
#  'Stroma',
#  'Necrosis',
#  'Tumor',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Stroma',
#  'Muscular',
#  'Stroma',
#  'Fat',
#  'Fat',
#  'Gland',
#  'Epithelium',
#  'Muscular',
#  'Stroma',
#  'Vein',
#  'Necrosis',
#  'Muscular',
#  'Tumor',
#  'Stroma',
#  'Stroma',
#  'Muscular',
#  'Muscular',
#  'Gland',
#  'Stroma',
#  'Tumor',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Fat',
#  'Necrosis',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Tumor',
#  'Tumor',
#  'Muscular',
#  'Vein',
#  'Necrosis',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Fat',
#  'Muscular',
#  'Vein',
#  'Necrosis',
#  'Muscular',
#  'Tumor',
#  'Muscular',
#  'Muscular',
#  'Fat',
#  'Muscular',
#  'Stroma',
#  'Muscular',
#  'Fat',
#  'Vein',
#  'Muscular',
#  'Stroma',
#  'Gland',
#  'Gland',
#  'Stroma',
#  'Muscular',
#  'Epithelium',
#  'Fat',
#  'Fat',
#  'Muscular',
#  'Tumor',
#  'Fat',
#  'Necrosis',
#  'Muscular',
#  'Gland',
#  'Tumor',
#  'Vein',
#  'Gland',
#  'Necrosis',
#  'Muscular',
#  'Stroma',
#  'Necrosis',
#  'Muscular',
#  'Tumor',
#  'Stroma',
#  'Muscular',
#  'Stroma',
#  'Stroma',
#  'Muscular',
#  'Tumor',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Gland',
#  'Fat',
#  'Muscular',
#  'Muscular',
#  'Tumor',
#  'Stroma',
#  'Muscular',
#  'Muscular',
#  'Epithelium',
#  'Tumor',
#  'Epithelium',
#  'Vein',
#  'Muscular',
#  'Vein',
#  'Gland',
#  'Necrosis',
#  'Vein',
#  'Stroma',
#  'Vein',
#  'Vein',
#  'Muscular',
#  'Vein',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Vein',
#  'Fat',
#  'Muscular',
#  'Epithelium',
#  'Necrosis',
#  'Muscular',
#  'Vein',
#  'Vein',
#  'Tumor',
#  'Vein',
#  'Vein',
#  'Fat',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Epithelium',
#  'Stroma',
#  'Stroma',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Vein',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Tumor',
#  'Fat',
#  'Tumor',
#  'Muscular',
#  'Muscular',
#  'Epithelium',
#  'Fat',
#  'Stroma',
#  'Muscular',
#  'Tumor',
#  'Epithelium',
#  'Fat',
#  'Tumor',
#  'Muscular',
#  'Muscular',
#  'Tumor',
#  'Muscular',
#  'Gland',
#  'Muscular',
#  'Necrosis',
#  'Stroma',
#  'Muscular',
#  'Necrosis',
#  'Tumor',
#  'Fat',
#  'Stroma',
#  'Vein',
#  'Necrosis',
#  'Muscular',
#  'Stroma',
#  'Gland',
#  'Muscular',
#  'Tumor',
#  'Fat',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Epithelium',
#  'Vein',
#  'Muscular',
#  'Vein',
#  'Fat',
#  'Muscular',
#  'Muscular',
#  'Gland',
#  'Stroma',
#  'Stroma',
#  'Muscular',
#  'Vein',
#  'Tumor',
#  'Muscular',
#  'Gland',
#  'Vein',
#  'Epithelium',
#  'Necrosis',
#  'Tumor',
#  'Vein',
#  'Tumor',
#  'Muscular',
#  'Stroma',
#  'Epithelium',
#  'Vein',
#  'Fat',
#  'Muscular',
#  'Fat',
#  'Epithelium',
#  'Stroma',
#  'Fat',
#  'Vein',
#  'Stroma',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Tumor',
#  'Muscular',
#  'Vein',
#  'Epithelium',
#  'Stroma',
#  'Fat',
#  'Epithelium',
#  'Necrosis',
#  'Tumor',
#  'Vein',
#  'Muscular',
#  'Stroma',
#  'Stroma',
#  'Stroma',
#  'Muscular',
#  'Vein',
#  'Necrosis',
#  'Fat',
#  'Tumor',
#  'Gland',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Epithelium',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Fat',
#  'Vein',
#  'Muscular',
#  'Stroma',
#  'Vein',
#  'Fat',
#  'Gland',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Fat',
#  'Tumor',
#  'Fat',
#  'Vein',
#  'Stroma',
#  'Muscular',
#  'Necrosis',
#  'Muscular',
#  'Tumor',
#  'Muscular',
#  'Stroma',
#  'Muscular',
#  'Tumor',
#  'Vein',
#  'Vein',
#  'Vein',
#  'Vein',
#  'Vein',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Gland',
#  'Vein',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Necrosis',
#  'Muscular',
#  'Necrosis',
#  'Tumor',
#  'Necrosis',
#  'Stroma',
#  'Epithelium',
#  'Necrosis',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Gland',
#  'Muscular',
#  'Tumor',
#  'Tumor',
#  'Tumor',
#  'Necrosis',
#  'Necrosis',
#  'Tumor',
#  'Muscular',
#  'Gland',
#  'Necrosis',
#  'Muscular',
#  'Muscular',
#  'Stroma',
#  'Vein',
#  'Epithelium',
#  'Muscular',
#  'Necrosis',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Stroma',
#  'Muscular',
#  'Fat',
#  'Gland',
#  'Fat',
#  'Tumor',
#  'Vein',
#  'Tumor',
#  'Muscular',
#  'Muscular',
#  'Fat',
#  'Muscular',
#  'Muscular',
#  'Fat',
#  'Necrosis',
#  'Tumor',
#  'Muscular',
#  'Gland',
#  'Gland',
#  'Epithelium',
#  'Muscular',
#  'Vein',
#  'Vein',
#  'Muscular',
#  'Fat',
#  'Epithelium',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Tumor',
#  'Fat',
#  'Epithelium',
#  'Gland',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Stroma',
#  'Muscular',
#  'Muscular',
#  'Vein',
#  'Necrosis',
#  'Muscular',
#  'Stroma',
#  'Gland',
#  'Gland',
#  'Vein',
#  'Muscular',
#  'Vein',
#  'Muscular',
#  'Muscular',
#  'Epithelium',
#  'Tumor',
#  'Gland',
#  'Stroma',
#  'Muscular',
#  'Muscular',
#  'Tumor',
#  'Muscular',
#  'Fat',
#  'Vein',
#  'Necrosis',
#  'Epithelium',
#  'Muscular',
#  'Muscular',
#  'Muscular',
#  'Tumor',
#  'Vein',
#  'Necrosis',
#  'Muscular',
#  'Tumor',
#  'Stroma',
#  'Necrosis',
#  'Necrosis',
#  'Muscular',
#  'Stroma',
#  'Muscular',
#  'Fat',
#  'Vein',
#  'Vein',
#  'Muscular',
#  'Vein',
#  'Stroma',
#  'Muscular',
#  'Necrosis',
#  'Vein',
#  'Stroma',
#  'Fat',
#  'Stroma',
#  'Necrosis',
#  'Tumor',
#  'Muscular',
#  'Fat',
#  'Muscular',
#  'Gland',
#  'Necrosis',
#  'Fat',
#  'Fat',
#  'Vein',
#  'Stroma',
#  'Necrosis',
#  'Tumor',
#  'Vein',
#  'Necrosis',
#  'Epithelium',
#  'Muscular',
#  'Necrosis',
#  'Necrosis',
#  'Stroma',
#  'Tumor',
#  'Vein',
#  'Fat',
#  'Tumor',
#  'Necrosis',
#  'Fat',
#  ...]

# %%
# %matplotlib notebook
cdict = ['tab:blue','tab:orange','tab:red','tab:brown','tab:pink', 'tab:green', 'tab:cyan', 'tab:purple']
plt.rcParams["figure.figsize"] = [10, 20]
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img)
ax2.imshow(img)
for i in range(len(class_names)):
    c = [cs[j] for j in range(len(centers)) if clusterids[j]==i]
    r = [rs[j] for j in range(len(centers)) if clusterids[j]==i]
    cl = [x for x in clusterids if x == i]  
    scatter = ax1.scatter(c, r, c=cdict[i], label = class_names[i], s=0.5)

# produce a legend with the unique colors from the scatter
legend1 = ax1.legend(loc="upper center", ncol=3, fancybox=False)
ax1.add_artist(legend1)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig.savefig('out-'+ fname, bbox_inches='tight', dpi=1000)

# %%
from collections import Counter
Counter(clusterids)
# Out:
# Counter({2: 4765,
#          3: 3191,
#          1: 19053,
#          6: 3964,
#          7: 2582,
#          4: 5975,
#          0: 5405,
#          5: 5065})

# %%
class_names

# %% [markdown]
# # Generate output for all the images in the folder

# %%
plt.rcParams["figure.figsize"] = [10, 20]
fig, ax = plt.subplots()
ax.imshow(img)

# %%
# %matplolib inline
clusterids = list(clusterids)
clusterids 
c = [cs[j] for j in range(len(centers)) if clusterids[j]==1]
r = [rs[j] for j in range(len(centers)) if clusterids[j]==1]
cl = [cl for cl in clusterids if cl==1]
#plot the points
ax.scatter(c, r, c = 'red', label = 1, s = 1)
#create legend
ax.legend() 
plt.show()

# %%
#plot the image
    plt.rcParams["figure.figsize"] = [10, 20]
    fig, ax = plt.subplots()
    ax.imshow(img)
    clusterids = list(clusterids)
    for i in range(len(class_names)): 
        c = [cs[j] for j in range(len(centers)) if clusterids[j]==i]
        r = [rs[j] for j in range(len(centers)) if clusterids[j]==i]
        cl = [cl for cl in clusterids if cl==i]
        #plot the points
        ax.scatter(c, r, label=class_names[i], c=i, s=1)
        #create legend
    ax.legend() 
    
    fig.savefig('out-'+ fname, bbox_inches='tight')
